# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah4184/BASIC-PYTHON/blob/main/TUPLE_OF_BASIC_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tuple_1 = ('Artifical intelligence', 'Computer science', 'IT')
tuple_2 = tuple_1
print(tuple_1)
print(tuple_2)
# Out:
# ('Artifical intelligence', 'Computer science', 'IT')
# ('Artifical intelligence', 'Computer science', 'IT')
