# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah4184/BASIC-PYTHON/blob/main/SETS_OF_BASIC_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subjects = {'maths', 'english', 'science' }
print(subjects)
# Out:
# {'science', 'maths', 'english'}

# %%
print('maths', 'english', 'science' in subjects)
# Out:
# maths english True

# %%
elements = {'Art', 'history', 'social studies', 'english'}
print(subjects.intersection(elements))
# Out:
# {'english'}

# %%
print(subjects.union(elements))
# Out:
# {'history', 'science', 'social studies', 'english', 'Art', 'maths'}

# %%
from re import sub
print(subjects.difference(elements))
# Out:
# {'science', 'maths'}
