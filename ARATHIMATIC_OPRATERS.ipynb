# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah4184/BASIC-PYTHON/blob/main/ARATHIMATIC_OPRATERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
asd = 29
dsa = 28
print(asd<dsa)
# Out:
# False

# %%
fsd = 58
sdf = 60
print(fsd<sdf)
# Out:
# True

# %%
rsd = 42
dsr = 42
print(rsd == dsr)
# Out:
# True

# %%
a = 7
b = 7
print(a + b)
# Out:
# 14

# %%
d = 8
e = 5
print(d - e)
# Out:
# 3

# %%
t = 10
r = 10
print(t * r)
# Out:
# 100

# %%
h = 81
g = 9
print(h / g)
# Out:
# 9.0

# %%
 j = 80
 l = 7
 print(j % l)
# Out:
# 3

# %%
m = 6
n = 4
print(m ** n)
# Out:
# 1296
