# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah4184/BASIC-PYTHON/blob/main/LIST_BAISC_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course = ['hindi', 'urdu', 'riazi']
print(course)
# Out:
# ['hindi', 'urdu', 'riazi']

# %%
print(len(course))
# Out:
# 3

# %%
print(course[0:1])
# Out:
# ['hindi']

# %%
print(course[-1])
# Out:
# riazi

# %%
subjects = [1 , 2, 3, 4, 5, 6, 7, 8]
print(subjects)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
subjects.append(9.456)
print(subjects)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 9.456]

# %%
subjects.insert(-1 , 876)
print(subjects)
# Out:
# [876, 1, 2, 3, 4, 5, 876, 6, 7, 8, 9, 876, 9.456]

# %%
jin = ['kela' , 'saib', 'lasan']
lon = ['amrod' , 'malta']
jin.extend(lon)
print(jin)
# Out:
# ['kela', 'saib', 'lasan', 'amrod', 'malta']

# %%
jin.remove('amrod')
print(jin)
# Out:
# ['kela', 'saib', 'lasan', 'malta']

# %%
jin.reverse()
print(jin)
# Out:
# ['malta', 'lasan', 'saib', 'kela']

# %%
jin.insert(1,'amrodu')
print(jin)
# Out:
# ['malta', 'amrodu', 'amrod', 'lasan', 'amrod', 'saib', 'kela']

# %%
jin.reverse()
print(jin)
# Out:
# ['kela', 'saib', 'amrod', 'lasan', 'amrod', 'amrodu', 'malta']

# %%
jin.pop()
print(jin)
# Out:
# ['kela', 'saib', 'amrod', 'lasan', 'amrod', 'amrodu']

# %%
jin.pop()
print(jin)
# Out:
# ['kela', 'saib', 'amrod', 'lasan', 'amrod']

# %%
jin.pop()
print(jin)
# Out:
# ['kela', 'saib', 'amrod', 'lasan']

# %%
jin.pop()
print(jin)
# Out:
# ['kela', 'saib', 'amrod']

# %%
jin.pop()
print(jin)
# Out:
# ['kela', 'saib']

# %%
jin.pop()
print(jin)
# Out:
# ['kela']

# %%
jin.pop()
print(jin)
# Out:
# []

# %%
jin.extend(lon)
print(jin)
# Out:
# ['amrod', 'malta']
